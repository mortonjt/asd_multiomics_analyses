# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Filter-out-interactions-based-on-taxonomy" data-toc-modified-id="Filter-out-interactions-based-on-taxonomy-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Filter out interactions based on taxonomy</a></span></li><li><span><a href="#Filter-out-microbes-based-on-taxonomy" data-toc-modified-id="Filter-out-microbes-based-on-taxonomy-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Filter out microbes based on taxonomy</a></span></li></ul></div>

# %%
# This block is just for importing the necessary libraries.  
import os
from collections import defaultdict
# Numerical libraries
import pandas as pd
import numpy as np
import biom
import arviz as az
from scipy.spatial.distance import euclidean
# Plotting libraries
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches
import seaborn as sns
from matplotlib_venn import venn2, venn3
# custom utility and plotting functions
from util import (extract_differentials, select_features, 
                  get_genomic_data, collapse_transcripts, 
                  aggregate_pathways,
                  ranking, btest, log_pvalue, read_kegg_dict,
                  ilr_transform_differentials,
                  rename_clades, create_projection,
                  match_all_differentials)
from plot import (rankplot, networkplot, vectorplot)
import random

# directory paths
dan_directory = '../sfari/data/sra_shotgun/Dan2020'
averina_directory = '../sfari/data/sra_shotgun/Averina2020'
wang_directory = '../sfari/data/sra_shotgun/Wang2021'
taxa_directory = '~/databases/wol/taxonomy'
taxa_directory = '~/databases/wol/taxonomy'
gtdb_directory = '~/databases/wol/taxonomy/gtdb'
results_dir = '../results'
mmvec_edge_dir = f'{results_dir}/mmvec/Network'
kegg_dir = f'{results_dir}/kegg'
hsa_dir = f'{results_dir}/hsa_kegg'
np.random.seed(0)
random.seed(0)
# %matplotlib inline

# %% [raw]
# # Load taxonomies
# taxids = pd.read_table(f'{taxa_directory}/taxid.map', header=None, dtype=str)
# ranks = pd.read_table(f'{taxa_directory}/ranks.tsv')
# taxonomy = pd.merge(ranks, taxids, left_on='genome', right_on=0)
# taxonomy = taxonomy.set_index(1)
# del taxonomy[0]

# %%
# Load taxonomies
taxids = pd.read_table(f'{taxa_directory}/taxid.map', header=None, dtype=str)
ranks = pd.read_table(f'{gtdb_directory}/ranks.tsv')
taxonomy = pd.merge(ranks, taxids, left_on='gid', right_on=0)
taxonomy = taxonomy.set_index(1)
del taxonomy[0]

# %%
def concat_slash(x):
    #k = x['kingdom']
    p = x['phylum']
    c = x['class']
    o = x['order']
    f = x['family']
    g = x['genus']
    s = x['species']
    return '/'.join(list(map(str, [p, c, o, f, g, s])))

# %%
wol_taxa = list(taxonomy.apply(concat_slash, axis=1).values)

# %%
gpd_metadata = pd.read_table('../results/mmvec/GPD_metadata.tsv')
gpd_metadata = gpd_metadata.dropna(subset=['Host_range_isolates'])

# %%
lookup = {
 'Actinobacteriota' : 'Actinobacteria',
 'Bacteroidota' : 'Bacteroidetes',
 'Desulfobacterota': 'Deltaproteobacteria',
 'Synergistota': 'Synergistetes',
 'Campylobacterota': 'Epsilonproteobacteria',
 'Fusobacteriota': 'Fusobacteria'}
    
def fix_f(x):
    y = x.split('/')[0]
    ## uncomment if you want to fix phylum level naming
    #if y in lookup.keys():
    #    z = lookup[y]
    #    return x.replace(y, z)
    return x
        
def all_taxa(x):
    if pd.isnull(x):
        return []
    else:
        taxa = str(x).split(',')
        return list(set(list(map(fix_f, taxa))))
    
gpd_taxa = list(gpd_metadata['Host_range_taxon'].apply(all_taxa).values)

# %% [markdown]
# # Filter out interactions based on taxonomy

# %%
all_gpd_taxa = sum(gpd_taxa, [])
all_gpd_taxa = set(all_gpd_taxa)
common_taxa = set(wol_taxa) & set(all_gpd_taxa)

# %%
def contains_f(x):
    return len(set(x) & common_taxa) > 0

idx = list(map(contains_f, gpd_taxa))

gpd_subset = gpd_metadata.loc[idx]
viruses = gpd_metadata.loc[idx, 'GPD_id']

# %%
averina_edges = pd.read_table(f'{mmvec_edge_dir}/edges_Averina.txt')
averina_edges = averina_edges.loc[averina_edges.cond_logit > 1]

dan_edges = pd.read_table(f'{mmvec_edge_dir}/edges_Dan.txt')
dan_edges = dan_edges.loc[dan_edges.cond_logit > 1]

pths_edges = pd.read_table(f'{mmvec_edge_dir}/edges_PTHS.txt')
pths_edges = pths_edges.loc[pths_edges.cond_logit > 1]

wang_edges = pd.read_table(f'{mmvec_edge_dir}/edges_Wang.txt')
wang_edges = wang_edges.loc[wang_edges.cond_logit > 1]

# %%
print(dan_edges.shape, wang_edges.shape, averina_edges.shape)
# Out:
# (23896, 3) (20584, 3) (34100, 3)

# %%
dan_edges.shape[0] + wang_edges.shape[0] + averina_edges.shape[0]
# Out:
# 78580

# %% [markdown]
# # Filter out microbes based on taxonomy

# %%
def contains_taxonomy(x):
    x = str(x)
    if x in taxonomy.index:
        tstr = concat_slash(taxonomy.loc[x])
        return tstr in common_taxa
    return False
wang_edges = wang_edges.loc[wang_edges.microbe.apply(contains_taxonomy)]
dan_edges = dan_edges.loc[dan_edges.microbe.apply(contains_taxonomy)]
averina_edges = averina_edges.loc[averina_edges.microbe.apply(contains_taxonomy)]
pths_edges = pths_edges.loc[pths_edges.microbe.apply(contains_taxonomy)]

# %%
print(dan_edges.shape, wang_edges.shape, averina_edges.shape)
# Out:
# (10626, 3) (10574, 3) (10076, 3)

# %%
dan_edges.shape[0] + wang_edges.shape[0] + averina_edges.shape[0]
# Out:
# 31276

# %%
wang_edges['dataset'] = 'Wang'
dan_edges['dataset'] = 'Dan'
averina_edges['dataset'] = 'Averina'
# pths_edges['dataset'] = 'PTHS'
all_edges = pd.concat((wang_edges, dan_edges, averina_edges), axis=0)

# %%
all_edges['microbe'] = all_edges['microbe'].astype(np.str)
# merge microbial metadata
all_edges = pd.merge(all_edges, gpd_metadata, left_on='virus', right_on='GPD_id')
# merge GPD metadata
all_edges = pd.merge(all_edges, taxonomy, left_on='microbe', right_index=True)
# Out:
# <ipython-input-16-097f4499dd13>:1: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   all_edges['microbe'] = all_edges['microbe'].astype(np.str)

# %%
all_edges.to_csv('../results/interaction_metadata.txt', sep='\t')

# %%
all_edges
# Out:
#       microbe        virus  cond_logit  dataset       GPD_id      Source  \
# 0     1262981  uvig_108002    4.954891     Wang  uvig_108002  Metagenome
# 22    1262981  uvig_108002    4.954891     Wang  uvig_108002  Metagenome
# 44    1262981    ivig_2376    4.954647     Wang    ivig_2376     Isolate
# 66    1262981    ivig_2376    4.954647     Wang    ivig_2376     Isolate
# 88    1262981    ivig_2256    4.915556     Wang    ivig_2256     Isolate
# ...       ...          ...         ...      ...          ...         ...
# 6007  1871003  uvig_492171    1.052579  Averina  uvig_492171  Metagenome
# 6041  1871003  uvig_568287    1.173307  Averina  uvig_568287  Metagenome
# 6066  1871003  uvig_568287    1.173307  Averina  uvig_568287  Metagenome
# 6189  1871003    ivig_4295    1.122697  Averina    ivig_4295     Isolate
# 6212  1871003    ivig_4295    1.122697  Averina    ivig_4295     Isolate
#
#       GPD_VC    Size Predicted_phage_taxon  \
# 0      37815   32601            Myoviridae
# 22     37815   32601            Myoviridae
# 44     18797   40415                   NaN
# 66     18797   40415                   NaN
# 88     41768   39592                   NaN
# ...      ...     ...                   ...
# 6007    3999   59704                   NaN
# 6041     908  119423                   NaN
# 6066     908  119423                   NaN
# 6189   18307   23261                   NaN
# 6212   18307   23261                   NaN
#
#                                     Host_range_isolates  ... checkV_termini  \
# 0     GCA_003464755,GCF_000164195,12718_7#19,20298_3...  ...             No
# 22    GCA_003464755,GCF_000164195,12718_7#19,20298_3...  ...             No
# 44                                        GCF_000011045  ...             No
# 66                                        GCF_000011045  ...             No
# 88                                        GCA_003602765  ...             No
# ...                                                 ...  ...            ...
# 6007                                      GCA_003482185  ...             No
# 6041                           12718_7#33,GCA_003466785  ...             No
# 6066                           12718_7#33,GCA_003466785  ...             No
# 6189                                          21673_4#3  ...             No
# 6212                                          21673_4#3  ...             No
#
#      Novel         gid    domain        phylum        class  \
# 0      Yes  G000435955  Bacteria    Firmicutes      Bacilli
# 22     Yes  G000435955  Bacteria    Firmicutes      Bacilli
# 44     Yes  G000435955  Bacteria    Firmicutes      Bacilli
# 66     Yes  G000435955  Bacteria    Firmicutes      Bacilli
# 88     Yes  G000435955  Bacteria    Firmicutes      Bacilli
# ...    ...         ...       ...           ...          ...
# 6007   Yes  G900104605  Bacteria  Bacteroidota  Bacteroidia
# 6041    No  G900104605  Bacteria  Bacteroidota  Bacteroidia
# 6066    No  G900104605  Bacteria  Bacteroidota  Bacteroidia
# 6189    No  G900104605  Bacteria  Bacteroidota  Bacteroidia
# 6212    No  G900104605  Bacteria  Bacteroidota  Bacteroidia
#
#                    order               family          genus  \
# 0     Erysipelotrichales  Erysipelotrichaceae  Eubacterium_D
# 22    Erysipelotrichales  Erysipelotrichaceae  Eubacterium_D
# 44    Erysipelotrichales  Erysipelotrichaceae  Eubacterium_D
# 66    Erysipelotrichales  Erysipelotrichaceae  Eubacterium_D
# 88    Erysipelotrichales  Erysipelotrichaceae  Eubacterium_D
# ...                  ...                  ...            ...
# 6007       Bacteroidales        Rikenellaceae  Tidjanibacter
# 6041       Bacteroidales        Rikenellaceae  Tidjanibacter
# 6066       Bacteroidales        Rikenellaceae  Tidjanibacter
# 6189       Bacteroidales        Rikenellaceae  Tidjanibacter
# 6212       Bacteroidales        Rikenellaceae  Tidjanibacter
#
#                          species
# 0         Eubacterium_D innocuum
# 22        Eubacterium_D innocuum
# 44        Eubacterium_D innocuum
# 66        Eubacterium_D innocuum
# 88        Eubacterium_D innocuum
# ...                          ...
# 6007  Tidjanibacter massiliensis
# 6041  Tidjanibacter massiliensis
# 6066  Tidjanibacter massiliensis
# 6189  Tidjanibacter massiliensis
# 6212  Tidjanibacter massiliensis
#
# [6530 rows x 29 columns]

# %%
taxonomy
# Out:
#                 gid    domain            phylum                class  \
# 1
# 398511   G000005825  Bacteria        Firmicutes              Bacilli
# 456320   G000006175   Archaea     Euryarchaeota         Methanococci
# 306537   G000006605  Bacteria  Actinobacteriota       Actinobacteria
# 160492   G000006725  Bacteria    Proteobacteria  Gammaproteobacteria
# 243277   G000006745  Bacteria    Proteobacteria  Gammaproteobacteria
# ...             ...       ...               ...                  ...
# 484498   G900156675  Bacteria    Proteobacteria  Gammaproteobacteria
# 477680   G900156765  Bacteria      Bacteroidota          Bacteroidia
# 1926284  G900156885  Bacteria        Firmicutes              Bacilli
# 1926277  G900156915  Bacteria        Firmicutes              Bacilli
# 1255658  G900163845  Bacteria  Actinobacteriota       Actinobacteria
#
#                        order                family               genus  \
# 1
# 398511            Bacillales         Bacillaceae_D          Bacillus_S
# 456320       Methanococcales      Methanococcaceae       Methanococcus
# 306537     Corynebacteriales    Corynebacteriaceae     Corynebacterium
# 160492       Xanthomonadales      Xanthomonadaceae             Xylella
# 243277      Enterobacterales          Vibrionaceae              Vibrio
# ...                      ...                   ...                 ...
# 484498       Pseudomonadales  Saccharospirillaceae          Oleibacter
# 477680       Chitinophagales      Chitinophagaceae           Filimonas
# 1926284      Lactobacillales      Lactobacillaceae     Lactobacillus_H
# 1926277           Bacillales      Amphibacillaceae  Sediminibacillus_A
# 1255658  Propionibacteriales  Propionibacteriaceae         Luteococcus
#
#                                  species
# 1
# 398511           Bacillus_S pseudofirmus
# 456320              Methanococcus voltae
# 306537          Corynebacterium jeikeium
# 160492                Xylella fastidiosa
# 243277                   Vibrio cholerae
# ...                                  ...
# 484498                Oleibacter marinus
# 477680                 Filimonas lacunae
# 1926284                              NaN
# 1926277  Sediminibacillus_A massiliensis
# 1255658            Luteococcus japonicus
#
# [9732 rows x 8 columns]
